# %%
# importing libraries
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np

# %%
#Optional for disabling warnings 
import sys
if not sys.warnoptions:
    import warnings
    warnings.simplefilter("ignore")

# %%
#Set figure resolution to 300dpi
import matplotlib as mpl
# %matplotlib inline
plt.rcParams['figure.dpi'] = 300
plt.rcParams['savefig.dpi'] = 300

# %%
df = pd.read_excel (r'./MicrobialCell_Run1.xlsx', index_col=0) 
df
# Out:
#         mV
# Day
# 0      7.0
# 3     39.9
# 6    320.0
# 8    389.0

# %%
fig, ax = plt.subplots()
df.plot.line(ax=ax, y='mV', color='r', marker='o', label='Microbial Voltage Production')
ax.set_xlabel("Time (Days)")
ax.set_ylabel("Voltage Generated (mV)")
ax.set_title("Microbial Fuel Cell Energy Production - Run 1 (Mud)")
ax.legend()
